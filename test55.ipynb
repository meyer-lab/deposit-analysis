# %%
#imports
from functions import blurring, one_plot
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import LeaveOneOut

# %%
#data loading for experiment 55
a = blurring("data/exp55/Control/")
b = blurring('data/exp55/Treatment/')
image_matrix = np.concatenate((a, b))
# Out:
# 100%|██████████| 9/9 [00:10<00:00,  1.16s/it]
# 100%|██████████| 9/9 [00:09<00:00,  1.09s/it]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score
lr = LogisticRegression()

Y = np.zeros(image_matrix.shape[0], dtype=bool)
Y[9::] = 1

Y_pred = cross_val_predict(lr, image_matrix, Y, cv=LeaveOneOut())
print(accuracy_score(Y, Y_pred))

lr.fit(image_matrix, Y)
plt.plot(lr.coef_.T);
# Out:
# 0.6111111111111112

# %%
Y_pred = cross_val_predict(lr, image_matrix[:, 0:20], Y, cv=LeaveOneOut())
print(accuracy_score(Y, Y_pred))
# Out:
# 0.6111111111111112

# %%
#generate plots
y_val55c = blurring('data/exp55/Control/')
one_plot(y_val55c, 'experiment 55 Control')

y_val55t = blurring('data/exp55/Treatment/')
one_plot(y_val55t, 'experiment 55 Treatment')
# Out:
# 100%|██████████| 9/9 [00:20<00:00,  2.31s/it]
# 100%|██████████| 9/9 [00:21<00:00,  2.43s/it]
