# %%
#imports
from functions import blurring, one_plot
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import LeaveOneOut

# %%
#data loading for experiment 55
a = blurring("data/exp48.49/Control/")
b = blurring('data/exp48.49/Treatment/')
image_matrix = np.concatenate((a, b))
# Out:
# 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# 100%|██████████| 12/12 [00:11<00:00,  1.02it/s]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score
lr = LogisticRegression()

Y = np.zeros(image_matrix.shape[0], dtype=bool)
Y[12::] = 1

Y_pred = cross_val_predict(lr, image_matrix, Y, cv=LeaveOneOut())
print(accuracy_score(Y, Y_pred))

lr.fit(image_matrix, Y)
plt.plot(lr.coef_.T);
# Out:
# 0.6363636363636364

# %%
Y_pred = cross_val_predict(lr, image_matrix[:, 0:20], Y, cv=LeaveOneOut())
print(accuracy_score(Y, Y_pred))
# Out:
# 0.5454545454545454

# %%
y_val4c = blurring('data/exp48.49/Control/')
one_plot(y_val4c, 'experiment 48 49 Control')

y_val4c = blurring('data/exp48.49/Treatment/')
one_plot(y_val4c, 'experiment 48 49 Treatment')
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.43it/s]
# 100%|██████████| 12/12 [00:08<00:00,  1.48it/s]
